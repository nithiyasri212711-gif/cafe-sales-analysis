# %%
import pandas as pd
import warnings
import numpy as np
warnings.filterwarnings('ignore')
df=pd.read_csv("C:\Downloads\dirty_cafe_sales.csv")

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df.dtypes
# Out:
# Transaction ID      object
# Item                object
# Quantity            object
# Price Per Unit      object
# Total Spent         object
# Payment Method      object
# Location            object
# Transaction Date    object
# dtype: object

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Payment Method', 'Location', 'Transaction Date'],
#       dtype='object')

# %%
df1=df[[ 'Item', 'Quantity', 'Price Per Unit', 'Total Spent']]

# %%
df1
# Out:
#           Item Quantity Price Per Unit Total Spent
# 0       Coffee        2            2.0         4.0
# 1         Cake        4            3.0        12.0
# 2       Cookie        4            1.0       ERROR
# 3        Salad        2            5.0        10.0
# 4       Coffee        2            2.0         4.0
# ...        ...      ...            ...         ...
# 9995    Coffee        2            2.0         4.0
# 9996       NaN        3            NaN         3.0
# 9997    Coffee        4            2.0         8.0
# 9998    Cookie        3            NaN         3.0
# 9999  Sandwich        3            4.0        12.0
#
# [10000 rows x 4 columns]

# %%
df1.isnull().sum()
# Out:
# Item              333
# Quantity          138
# Price Per Unit    179
# Total Spent       173
# dtype: int64

# %%
df1.Item.unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', 'UNKNOWN',
#        'Sandwich', nan, 'ERROR', 'Juice', 'Tea'], dtype=object)

# %%
df1.Quantity.unique()
# Out:
# array(['2', '4', '5', '3', '1', 'ERROR', 'UNKNOWN', nan], dtype=object)

# %%
df1["Price Per Unit"].unique()
# Out:
# array(['2.0', '3.0', '1.0', '5.0', '4.0', '1.5', nan, 'ERROR', 'UNKNOWN'],
#       dtype=object)

# %%
df1['Total Spent'].unique()
# Out:
# array(['4.0', '12.0', 'ERROR', '10.0', '20.0', '9.0', '16.0', '15.0',
#        '25.0', '8.0', '5.0', '3.0', '6.0', nan, 'UNKNOWN', '2.0', '1.0',
#        '7.5', '4.5', '1.5'], dtype=object)

# %%
df1.replace({'ERROR':np.nan,'UNKNOWN':np.nan},inplace = True)

# %%
df.shape
# Out:
# (10000, 8)

# %%
df1.Item.unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', nan, 'Sandwich',
#        'Juice', 'Tea'], dtype=object)

# %%
df1.Quantity.unique()
# Out:
# array(['2', '4', '5', '3', '1', nan], dtype=object)

# %%
df1["Price Per Unit"].unique()
# Out:
# array(['2.0', '3.0', '1.0', '5.0', '4.0', '1.5', nan], dtype=object)

# %%
df1['Total Spent'].unique()
# Out:
# array(['4.0', '12.0', nan, '10.0', '20.0', '9.0', '16.0', '15.0', '25.0',
#        '8.0', '5.0', '3.0', '6.0', '2.0', '1.0', '7.5', '4.5', '1.5'],
#       dtype=object)

# %%
df1.dtypes
# Out:
# Item              object
# Quantity          object
# Price Per Unit    object
# Total Spent       object
# dtype: object

# %%
def datatype(x):
    return float(x)
a='11'
datatype(a)
# Out:
# 11.0

# %%
df1["Price Per Unit"]=df1["Price Per Unit"].apply(datatype)

# %%
df1["Price Per Unit"].unique()
# Out:
# array([2. , 3. , 1. , 5. , 4. , 1.5, nan])

# %%
df1["Quantity"]=df1.Quantity.apply(datatype)

# %%
df1["Quantity"].unique()
# Out:
# array([ 2.,  4.,  5.,  3.,  1., nan])

# %%
df1['Total Spent']=df1['Total Spent'].apply(datatype)

# %%
df1
# Out:
#           Item  Quantity  Price Per Unit  Total Spent
# 0       Coffee       2.0             2.0          4.0
# 1         Cake       4.0             3.0         12.0
# 2       Cookie       4.0             1.0          NaN
# 3        Salad       2.0             5.0         10.0
# 4       Coffee       2.0             2.0          4.0
# ...        ...       ...             ...          ...
# 9995    Coffee       2.0             2.0          4.0
# 9996       NaN       3.0             NaN          3.0
# 9997    Coffee       4.0             2.0          8.0
# 9998    Cookie       3.0             NaN          3.0
# 9999  Sandwich       3.0             4.0         12.0
#
# [10000 rows x 4 columns]

# %%
df1.Item.unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', nan, 'Sandwich',
#        'Juice', 'Tea'], dtype=object)

# %%
df1[df1['Item'] == 'Coffee']['Price Per Unit'].unique()
# Out:
# array([ 2., nan])

# %%
df1[df1['Item'] == 'Tea']['Price Per Unit'].unique()
# Out:
# array([1.5, nan])

# %%
df1[df1['Item'] == 'Cake']['Price Per Unit'].unique()
# Out:
# array([ 3., nan])

# %%
df1[df1['Item']=='Cookie']['Price Per Unit'].unique()
# Out:
# array([ 1., nan])

# %%
df1[df1['Item']=='Salad']['Price Per Unit'].unique()
# Out:
# array([ 5., nan])

# %%
df1[df1['Item']=='Smoothie']['Price Per Unit'].unique()
# Out:
# array([ 4., nan])

# %%
df1[df1['Item']=='Sandwich']['Price Per Unit'].unique()
# Out:
# array([ 4., nan])

# %%
df1[df1['Item']=='Juice']['Price Per Unit'].unique()
# Out:
# array([ 3., nan])

# %%
df1['Total Spent'].unique()
# Out:
# array([ 4. , 12. ,  nan, 10. , 20. ,  9. , 16. , 15. , 25. ,  8. ,  5. ,
#         3. ,  6. ,  2. ,  1. ,  7.5,  4.5,  1.5])

# %%
df1['New_price']=df1['Total Spent']/df1['Quantity']

# %%
df1['New_price']
# Out:
# 0       2.0
# 1       3.0
# 2       NaN
# 3       5.0
# 4       2.0
#        ...
# 9995    2.0
# 9996    1.0
# 9997    2.0
# 9998    1.0
# 9999    4.0
# Name: New_price, Length: 10000, dtype: float64

# %%
df1
# Out:
#           Item  Quantity  Price Per Unit  Total Spent  New_price
# 0       Coffee       2.0             2.0          4.0        2.0
# 1         Cake       4.0             3.0         12.0        3.0
# 2       Cookie       4.0             1.0          NaN        NaN
# 3        Salad       2.0             5.0         10.0        5.0
# 4       Coffee       2.0             2.0          4.0        2.0
# ...        ...       ...             ...          ...        ...
# 9995    Coffee       2.0             2.0          4.0        2.0
# 9996       NaN       3.0             NaN          3.0        1.0
# 9997    Coffee       4.0             2.0          8.0        2.0
# 9998    Cookie       3.0             NaN          3.0        1.0
# 9999  Sandwich       3.0             4.0         12.0        4.0
#
# [10000 rows x 5 columns]

# %%
df1['New_price']=df1["New_price"].fillna(df1["Price Per Unit"])

# %%
df1["New_price"].unique()
# Out:
# array([2. , 3. , 1. , 5. , 4. , 1.5, nan])

# %%
df1
# Out:
#           Item  Quantity  Price Per Unit  Total Spent  New_price
# 0       Coffee       2.0             2.0          4.0        2.0
# 1         Cake       4.0             3.0         12.0        3.0
# 2       Cookie       4.0             1.0          NaN        1.0
# 3        Salad       2.0             5.0         10.0        5.0
# 4       Coffee       2.0             2.0          4.0        2.0
# ...        ...       ...             ...          ...        ...
# 9995    Coffee       2.0             2.0          4.0        2.0
# 9996       NaN       3.0             NaN          3.0        1.0
# 9997    Coffee       4.0             2.0          8.0        2.0
# 9998    Cookie       3.0             NaN          3.0        1.0
# 9999  Sandwich       3.0             4.0         12.0        4.0
#
# [10000 rows x 5 columns]

# %%
df1["New_Quantity"]=df1["Total Spent"]/df1['New_price']

# %%
df1["New_Quantity"]
# Out:
# 0       2.0
# 1       4.0
# 2       NaN
# 3       2.0
# 4       2.0
#        ...
# 9995    2.0
# 9996    3.0
# 9997    4.0
# 9998    3.0
# 9999    3.0
# Name: New_Quantity, Length: 10000, dtype: float64

# %%
df1["New_Quantity"]=df1["New_Quantity"].fillna(df1['Quantity'])

# %%
df1["New_Quantity"]
# Out:
# 0       2.0
# 1       4.0
# 2       4.0
# 3       2.0
# 4       2.0
#        ...
# 9995    2.0
# 9996    3.0
# 9997    4.0
# 9998    3.0
# 9999    3.0
# Name: New_Quantity, Length: 10000, dtype: float64

# %%
df1['New_Total']=df1['New_Quantity']*df1['New_price']

# %%
df1['New_Total']=df1['New_Total'].fillna(df1['Total Spent'])

# %%
df1['New_Total']
# Out:
# 0        4.0
# 1       12.0
# 2        4.0
# 3       10.0
# 4        4.0
#         ...
# 9995     4.0
# 9996     3.0
# 9997     8.0
# 9998     3.0
# 9999    12.0
# Name: New_Total, Length: 10000, dtype: float64

# %%
df1
# Out:
#           Item  Quantity  Price Per Unit  Total Spent  New_price  \
# 0       Coffee       2.0             2.0          4.0        2.0
# 1         Cake       4.0             3.0         12.0        3.0
# 2       Cookie       4.0             1.0          NaN        1.0
# 3        Salad       2.0             5.0         10.0        5.0
# 4       Coffee       2.0             2.0          4.0        2.0
# ...        ...       ...             ...          ...        ...
# 9995    Coffee       2.0             2.0          4.0        2.0
# 9996       NaN       3.0             NaN          3.0        1.0
# 9997    Coffee       4.0             2.0          8.0        2.0
# 9998    Cookie       3.0             NaN          3.0        1.0
# 9999  Sandwich       3.0             4.0         12.0        4.0
#
#       New_Quantity  New_Total
# 0              2.0        4.0
# 1              4.0       12.0
# 2              4.0        4.0
# 3              2.0       10.0
# ...

# %%
df1.New_price.unique()
# Out:
# array([2. , 3. , 1. , 5. , 4. , 1.5, nan])

# %%
df1.New_Quantity.unique()
# Out:
# array([ 2.,  4.,  5.,  3.,  1., nan])

# %%
df1.New_Total.unique()
# Out:
# array([ 4. , 12. , 10. , 20. ,  9. , 16. , 15. , 25. ,  8. ,  5. ,  3. ,
#         6. ,  2. ,  nan,  1. ,  7.5,  4.5,  1.5])

# %%
df1.columns
# Out:
# Index(['Item', 'Quantity', 'Price Per Unit', 'Total Spent', 'New_price',
#        'New_Quantity', 'New_Total'],
#       dtype='object')

# %%
df2=df1.drop(columns=['Quantity', 'Price Per Unit', 'Total Spent'])

# %%
df2
# Out:
#           Item  New_price  New_Quantity  New_Total
# 0       Coffee        2.0           2.0        4.0
# 1         Cake        3.0           4.0       12.0
# 2       Cookie        1.0           4.0        4.0
# 3        Salad        5.0           2.0       10.0
# 4       Coffee        2.0           2.0        4.0
# ...        ...        ...           ...        ...
# 9995    Coffee        2.0           2.0        4.0
# 9996       NaN        1.0           3.0        3.0
# 9997    Coffee        2.0           4.0        8.0
# 9998    Cookie        1.0           3.0        3.0
# 9999  Sandwich        4.0           3.0       12.0
#
# [10000 rows x 4 columns]

# %%
df2.isna().sum()
# Out:
# Item            969
# New_price        38
# New_Quantity     38
# New_Total        40
# dtype: int64

# %%
df2.New_price.unique()
# Out:
# array([2. , 3. , 1. , 5. , 4. , 1.5, nan])

# %%
price_1=df2.New_price==1

# %%
df2.columns
# Out:
# Index(['Item', 'New_price', 'New_Quantity', 'New_Total'], dtype='object')

# %%
df2.dtypes
# Out:
# Item             object
# New_price       float64
# New_Quantity    float64
# New_Total       float64
# dtype: object

# %%
df2.Item.unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', nan, 'Sandwich',
#        'Juice', 'Tea'], dtype=object)

# %%
cookie=df2.loc[price_1,['Item', 'New_price', 'New_Quantity', 'New_Total']]

# %%
cookie
# Out:
#         Item  New_price  New_Quantity  New_Total
# 2     Cookie        1.0           4.0        4.0
# 13    Cookie        1.0           5.0        5.0
# 26    Cookie        1.0           5.0        5.0
# 31       NaN        1.0           2.0        2.0
# 33       NaN        1.0           5.0        5.0
# ...      ...        ...           ...        ...
# 9956  Cookie        1.0           3.0        3.0
# 9976  Cookie        1.0           1.0        1.0
# 9982  Cookie        1.0           2.0        2.0
# 9996     NaN        1.0           3.0        3.0
# 9998  Cookie        1.0           3.0        3.0
#
# [1207 rows x 4 columns]

# %%
cookie.shape
# Out:
# (1207, 4)

# %%
cookie.isna().sum()
# Out:
# Item            121
# New_price         0
# New_Quantity      2
# New_Total         2
# dtype: int64

# %%
cookie.Item.unique()
# Out:
# array(['Cookie', nan], dtype=object)

# %%
cookie['Item'].replace([np.nan],'Cookie',inplace=True)

# %%
cookie.shape
# Out:
# (1207, 4)

# %%
cookie.Item.unique()
# Out:
# array(['Cookie'], dtype=object)

# %%
cookie=cookie.dropna(subset=['New_Total', 'New_Quantity'],how='all')

# %%
cookie.shape
# Out:
# (1205, 4)

# %%
cookie.isnull().sum()
# Out:
# Item            0
# New_price       0
# New_Quantity    0
# New_Total       0
# dtype: int64

# %%
cookie.shape
# Out:
# (1205, 4)

# %%
price_15=df2.New_price==1.5

# %%
tea=df2.loc[price_15,['Item','New_price','New_Quantity','New_Total']]

# %%
tea.shape
# Out:
# (1200, 4)

# %%
tea.Item.unique()
# Out:
# array([nan, 'Tea'], dtype=object)

# %%
tea['Item'].replace([np.nan],'Tea',inplace=True)

# %%
tea.Item.unique()
# Out:
# array(['Tea'], dtype=object)

# %%
tea.isna().sum()
# Out:
# Item            0
# New_price       0
# New_Quantity    1
# New_Total       1
# dtype: int64

# %%
tea=tea.dropna(subset=['New_Total', 'New_Quantity'],how='all')

# %%
tea.isna().sum()
# Out:
# Item            0
# New_price       0
# New_Quantity    0
# New_Total       0
# dtype: int64

# %%
price_2=df2.New_price==2

# %%
coffee=df2.loc[price_2,['Item','New_price','New_Quantity','New_Total']]

# %%
coffee.shape
# Out:
# (1289, 4)

# %%
coffee.Item.unique()
# Out:
# array(['Coffee', nan], dtype=object)

# %%
coffee['Item'].replace([np.nan],'Coffee',inplace=True)

# %%
coffee=coffee.dropna(subset=['New_Quantity','New_Total'],how='all')

# %%
coffee.isna().sum()
# Out:
# Item            0
# New_price       0
# New_Quantity    0
# New_Total       0
# dtype: int64

# %%
price_3=df2.New_price==3

# %%
cake=df2.loc[price_3,['Item','New_price','New_Quantity','New_Total']]

# %%
cake['Item'].replace([np.nan],'Cake',inplace=True)

# %%
cake=cake.dropna(subset=['New_Quantity','New_Total'],how='all')

# %%
cake.isna().sum()
# Out:
# Item            0
# New_price       0
# New_Quantity    0
# New_Total       0
# dtype: int64

# %%
price_4=df2.New_price==4

# %%
sandwich=df2.loc[price_4,['Item','New_price','New_Quantity','New_Total']]

# %%
sandwich['Item'].replace([np.nan],'Sandwich',inplace=True)

# %%
sandwich=sandwich.dropna(subset=['New_Quantity','New_Total'],how='all')

# %%
sandwich.isna().sum()
# Out:
# Item            0
# New_price       0
# New_Quantity    0
# New_Total       0
# dtype: int64

# %%
price_5=df2.New_price==5

# %%
salad=df2.loc[price_5,['Item','New_price','New_Quantity','New_Total']]

# %%
salad['Item'].replace([np.nan],'Salad',inplace=True)

# %%
salad=salad.dropna(subset=['New_Quantity','New_Total'],how='all')

# %%
salad.isna().sum()
# Out:
# Item            0
# New_price       0
# New_Quantity    0
# New_Total       0
# dtype: int64

# %%
price_null=df2.New_price.isnull()==True

# %%
price_null
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: New_price, Length: 10000, dtype: bool

# %%
price_null=df2.loc[price_null,['Item','New_price','New_Quantity','New_Total']]

# %%
price_null
# Out:
#           Item  New_price  New_Quantity  New_Total
# 65    Sandwich        NaN           3.0        NaN
# 629       Cake        NaN           NaN       12.0
# 912   Sandwich        NaN           NaN       20.0
# 1008       Tea        NaN           NaN        3.0
# 1436       Tea        NaN           NaN        6.0
# 1482  Smoothie        NaN           NaN       16.0
# 1674       Tea        NaN           2.0        NaN
# 1761       NaN        NaN           4.0        NaN
# 2229  Sandwich        NaN           2.0        NaN
# 2289       NaN        NaN           4.0        NaN
# 2330     Salad        NaN           NaN        5.0
# 2585       Tea        NaN           3.0        NaN
# 3162      Cake        NaN           3.0        NaN
# 3598  Smoothie        NaN           1.0        NaN
# 3635    Cookie        NaN           NaN        1.0
# 3673  Smoothie        NaN           2.0        NaN
# 3779       NaN        NaN           NaN       25.0
# ...

# %%
price_null.dropna(subset=['Item'],inplace=True)

# %%
price_null.shape
# Out:
# (32, 4)

# %%
price_null['Item'].isna().sum()
# Out:
# np.int64(0)

# %%
def price(x):
    if x=="Cookie":
        return 1
    elif x=='Tea':
        return 1.5
    elif x=='Coffee':
        return 2
    elif x=='Cake':
        return 3
    elif x=='Juice':
        return 3
    elif x=='Smothie':
        return 4
    elif x=='Sandwich':
        return 4
    else:
        return 5
a='Cake'
price(a)
# Out:
# 3

# %%
price_null['New_price']=price_null.Item.apply(price)

# %%
price_null['1 Quant']=price_null['New_Total']/price_null['New_price']

# %%
price_null
# Out:
#           Item  New_price  New_Quantity  New_Total  1 Quant
# 65    Sandwich        4.0           3.0        NaN      NaN
# 629       Cake        3.0           NaN       12.0      4.0
# 912   Sandwich        4.0           NaN       20.0      5.0
# 1008       Tea        1.5           NaN        3.0      2.0
# 1436       Tea        1.5           NaN        6.0      4.0
# 1482  Smoothie        5.0           NaN       16.0      3.2
# 1674       Tea        1.5           2.0        NaN      NaN
# 2229  Sandwich        4.0           2.0        NaN      NaN
# 2330     Salad        5.0           NaN        5.0      1.0
# 2585       Tea        1.5           3.0        NaN      NaN
# 3162      Cake        3.0           3.0        NaN      NaN
# 3598  Smoothie        5.0           1.0        NaN      NaN
# 3635    Cookie        1.0           NaN        1.0      1.0
# 3673  Smoothie        5.0           2.0        NaN      NaN
# 4021    Cookie        1.0           2.0        NaN      NaN
# ...

# %%
price_null['New_Quantity']=price_null['1 Quant'].fillna(price_null['New_Quantity'])

# %%
price_null['New_Total']=price_null['New_Quantity']*price_null['New_price']

# %%
price_null.drop('1 Quant',axis=1,inplace=True)

# %%
price_null
# Out:
#           Item  New_price  New_Quantity  New_Total
# 65    Sandwich        4.0           3.0       12.0
# 629       Cake        3.0           4.0       12.0
# 912   Sandwich        4.0           5.0       20.0
# 1008       Tea        1.5           2.0        3.0
# 1436       Tea        1.5           4.0        6.0
# 1482  Smoothie        5.0           3.2       16.0
# 1674       Tea        1.5           2.0        3.0
# 2229  Sandwich        4.0           2.0        8.0
# 2330     Salad        5.0           1.0        5.0
# 2585       Tea        1.5           3.0        4.5
# 3162      Cake        3.0           3.0        9.0
# 3598  Smoothie        5.0           1.0        5.0
# 3635    Cookie        1.0           1.0        1.0
# 3673  Smoothie        5.0           2.0       10.0
# 4021    Cookie        1.0           2.0        2.0
# 5639       Tea        1.5           4.0        6.0
# 5845  Smoothie        5.0           1.6        8.0
# ...

# %%
price_null.isna().sum()
# Out:
# Item            0
# New_price       0
# New_Quantity    0
# New_Total       0
# dtype: int64

# %%
price_null.dtypes
# Out:
# Item             object
# New_price       float64
# New_Quantity    float64
# New_Total       float64
# dtype: object

# %%
final_result=cookie._append([tea,price_2,price_3,price_4,price_5,price_null],ignore_index=True)

# %%
final_result
# Out:
#          Item  New_price  New_Quantity  New_Total    0
# 0      Cookie        1.0           4.0        4.0  NaN
# 1      Cookie        1.0           5.0        5.0  NaN
# 2      Cookie        1.0           5.0        5.0  NaN
# 3      Cookie        1.0           2.0        2.0  NaN
# 4      Cookie        1.0           5.0        5.0  NaN
# ...       ...        ...           ...        ...  ...
# 42431    Cake        3.0           1.0        3.0  NaN
# 42432     Tea        1.5           5.0        7.5  NaN
# 42433     Tea        1.5           1.0        1.5  NaN
# 42434    Cake        3.0           1.0        3.0  NaN
# 42435   Juice        3.0           2.0        6.0  NaN
#
# [42436 rows x 5 columns]

# %%
final_result.shape
# Out:
# (42436, 5)

# %%
final_result.isnull().sum()
# Out:
# Item            40000
# New_price       40000
# New_Quantity    40000
# New_Total       40000
# 0                2436
# dtype: int64
